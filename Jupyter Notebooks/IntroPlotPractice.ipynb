# %%
import csv
import numpy as np
file = open('NCAREarthCubeCHORDS_NCARMesaLab_MLWxStation.csv')
csv_reader = csv.reader(file)
next(csv_reader)
next(csv_reader)
next(csv_reader)
next(csv_reader)
next(csv_reader)
next(csv_reader)
next(csv_reader)
next(csv_reader)
next(csv_reader)
next(csv_reader)
next(csv_reader)
next(csv_reader)
next(csv_reader)
next(csv_reader)
next(csv_reader)
next(csv_reader)
next(csv_reader)
next(csv_reader)
#for row in csv_reader:
#   print(row)
# Out:
# ['# Units of Measure: milliseconds',
#  ' deg',
#  ' m/s',
#  ' m/s',
#  ' degC',
#  ' %',
#  ' mbar',
#  ' mm',
#  ' V']

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import figure
import csv
#Year, Month, Day, Zulu Time
#Grab day and hour, convert to hours
#Make a list for each of the variables
Time=[]
WindDir=[]
WindSpd=[]
WindMax=[]
Temp=[]
Humidity=[]
Pressure=[]
RainTot=[]
Battery=[]

with open('NCAREarthCubeCHORDS_NCARMesaLab_MLWxStation.csv', 'r') as csvfile:
    #Read the .csv file
    plots= csv.reader(csvfile, delimiter=',')
    #Skip the Header
    next(plots)
    next(plots)
    next(plots)
    next(plots)
    next(plots)
    next(plots)
    next(plots)
    next(plots)
    next(plots)
    next(plots)
    next(plots)
    next(plots)
    next(plots)
    next(plots)
    next(plots)
    next(plots)
    next(plots)
    next(plots)
    next(plots)
    for row in plots:
        #print(row)
        Time.append(row[0])
        WindDir.append(int(row[1]))
        WindSpd.append(float(row[2]))
        WindMax.append(float(row[3]))
        Temp.append(float(row[4]))
        Humidity.append(float(row[5]))
        Pressure.append(float(row[6]))
        RainTot.append(float(row[7]))
        Battery.append(float(row[8]))
        
Time1 = [s.strip('T') for s in Time]
Time2 = [s.replace('T', '') for s in Time1]
Time3 = [s.strip('Z') for s in Time2]
Time4 = [s.replace('Z', '') for s in Time3]
Time5 = [s.strip(':') for s in Time4]
Time6 = [s.replace(':', '') for s in Time5] 
Time7 = [s.strip('-') for s in Time6] 
Time8 = [s.replace('-', '') for s in Time7]
TimeList = [int(i) for i in Time8]

#print(TimeList)
plt.figure(figsize=(20,10))
plt.plot(TimeList, WindSpd)
#plt.xticks(np.arange(min(TimeList), max(TimeList)+1, 100000))
plt.title("Wind Speed over Time")
plt.xlabel('Time')
plt.ylabel('WindSpd')

#Try plot points. (via markers)
plt.figure(figsize=(20,10))
plt.scatter(TimeList, WindSpd)
#plt.xticks(np.arange(min(TimeList), max(TimeList)+1, 100000))
plt.title("Wind Speed over Time")
plt.xlabel('Time')
plt.ylabel('WindSpd')

TimeSub = []
for i in range(len(TimeList)):
    TimeSub.append(i*5)
#print(TimeSub)
#print(len(TimeSub))
#print(len(TimeList))

plt.figure(figsize=(20,10))
plt.plot(TimeSub, WindSpd)
#plt.xticks(np.arange(min(TimeList), max(TimeList)+1, 100000))
plt.title("Wind Speed over Time")
plt.xlabel('5-Min Time Intervals Elapsed Since 16:21:09Z')
plt.ylabel('WindSpd')
# Out:
# Text(0, 0.5, 'WindSpd')

# %%
import matplotlib.pyplot as plt
import numpy as np
nums = []
for i in range(10):
    nums.append(i*5)
print(nums)

time = ['1', '4', '5', '68', '90', '2', '34']
windDir = ['14', '19', '', '0', '90', '', '89']
windSpd = ['9', '10', '12', '40', '5', '82', '32']
import numpy as np
I = [2, 5]
np.delete(windDir, I).tolist()
# Out:
# [0, 5, 10, 15, 20, 25, 30, 35, 40, 45]
# ['14', '19', '0', '90', '89']

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import figure
import csv
#Year, Month, Day, Zulu Time
#Grab day and hour, convert to hours
#Make a list for each of the variables
Time=[]
WindDir=[]
WindSpd=[]

with open('NCAREarthCubeCHORDS_NCARMesaLab_MLSonic_2017Oct1-2018Mar31.csv', 'r') as csvfile:
    #Read the .csv file
    plots= csv.reader(csvfile, delimiter=',')
    #Skip the Header
    for row in plots:
        #print(row)
        Time.append(row[0])
        WindDir.append(row[1])
        WindSpd.append(row[2])

#for i in range(len(WindDir)):
#   print(WindDir[i])
Empty_values = []
for i in range(len(WindDir)):
    if(WindDir[i]==''):
        Empty_values.append(i)
#print(Empty_values)

#maybe assign missing value as null.

#Get rid of all the blank values in WindDir.
RevisedWind = []
RevisedWind = np.delete(WindDir, Empty_values).tolist()
RevisedWindSpd = []
RevisedWindSpd = np.delete(WindSpd, Empty_values).tolist()
RevisedTime = []
RevisedTime = np.delete(Time, Empty_values).tolist()

RWD = []
for i in range(len(RevisedWind)):
    RWD.append(int(RevisedWind[i]))
    
#Convert the missing values to some random value like 999
#Convert the list then to an integer.
#Convert those 999 values to something like None's.

#for i in range(0,10):
#    print(RevisedWind[i])
#    print(RWD[i])

#Here I checked to make sure the list was lacking any empty values.
#checker = []
#for i in range(len(RevisedWind)):
#   if(RevisedWind[i]==''):
#      checker.append(i)
#print(checker)
#for i in range(1, 10057):
#    print(RevisedWind[i])

#print(len(Empty_values))
#print(len(WindDir))
#print(len(RevisedWind))
#Checks out!

#print(len(RevisedWind))
#print(len(RevisedTime))
#print(len(RevisedWindSpd))

#2018-01-31T21:32:02Z
TimeSub = []
for i in range(len(RevisedTime)):
    TimeSub.append(i*5)

#Maybe take mean of time steps. For every 300 seconds starting at start time stamp, compute an average and store it into array.

plt.figure(figsize=(20,10))
plt.plot(TimeSub, RWD)
#plt.xticks(np.arange(min(TimeList), max(TimeList)+1, 100000))
plt.title("Wind Direction over Time")
plt.xlabel('5-Min Time Intervals Elapsed Since 2018-01-31T21:32:02Z')
plt.ylabel('WindDir')
# Out:
# Text(0, 0.5, 'WindDir')

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import figure
import csv
#Year, Month, Day, Zulu Time
#Grab day and hour, convert to hours
#Make a list for each of the variables
Time=[]
WindDir=[]
WindSpd=[]

with open('NCAREarthCubeCHORDS_NCARMesaLab_MLSonic_2017Oct1-2018Mar31.csv', 'r') as csvfile:
    #Read the .csv file
    plots= csv.reader(csvfile, delimiter=',')
    #Skip the Header
    for row in plots:
        #print(row)
        Time.append(row[0])
        WindDir.append(row[1])
        WindSpd.append(row[2])

#Cleaned Wind Speed
CWindSpd = list(map(lambda s: float(s) if s else None, WindSpd))

TimeSub = []
for i in range(len(Time)):
    TimeSub.append(i*5)

#Maybe take mean of time steps. For every 300 seconds starting at start time stamp, compute an average and store it into array.
plt.figure(figsize=(20,10))
plt.plot(TimeSub, CWindSpd)
#plt.xticks(np.arange(min(TimeList), max(TimeList)+1, 100000))
plt.title("Wind Speed over Time")
plt.xlabel('5-Min Time Intervals Elapsed Since 2018-01-31T21:32:02Z')
plt.ylabel('WindSpeed')
# Out:
# Text(0, 0.5, 'WindSpeed')

# %%
#Use Pandas and comma as delimiter.
import pandas as pd
df = pd.read_csv('s131Mhdfntjn', encoding='utf-8')
df.head(5)
# Out:
#                    datetime  Dir   Spd  Status        U       V
# 0  2018-01-24T19:13:01.0522    4  1.76    60.0 -0.12277 -1.7557
# 1  2018-01-24T19:13:02.0527  359  1.90    60.0  0.03316 -1.8997
# 2  2018-01-24T19:13:03.0496  354  2.27    60.0  0.23728 -2.2576
# 3  2018-01-24T19:13:04.0508  346  1.77    60.0  0.42820 -1.7174
# 4  2018-01-24T19:13:05.0520  342  1.33    60.0  0.41099 -1.2649

# %%
df.info()
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29410107 entries, 0 to 29410106
# Data columns (total 6 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   datetime  object
#  1   Dir       int64
#  2   Spd       float64
#  3   Status    float64
#  4   U         float64
#  5   V         float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 1.3+ GB

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import figure
import csv
df = pd.read_csv('RecentWindData1012-1014.csv', encoding='utf-8')
df2 = pd.read_csv('WindData1009-1011.csv', encoding = 'utf-8')

#df.head(18)
#df.info()

ax = df.plot(kind = 'line', x = 'Time', y = 'Wind Speed', color='red', figsize = (20, 10))
ax1 = df2.plot(kind = 'line', x = 'Time', y = 'Wind Speed', color='blue', figsize = (20, 10))
ax.set_xlabel("Time Elapsed From 10/12 to 10/14")
ax.set_ylabel("Wind Speed in m/s")
# Out:
# Text(0, 0.5, 'Wind Speed in m/s')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import figure
import csv

df = pd.read_csv('RecentWindData1012-1014.csv', encoding='utf-8')
df2 = pd.read_csv('WindData1009-1011.csv', encoding = 'utf-8')
ax = df.plot(kind = 'line', x = 'Time', y = 'Wind Speed', color='red', label = "Wind Speeds from 10/12 to 10/15", figsize = (20, 10))
df2.plot(kind = 'line', x = 'Time', y = 'Wind Speed', color='blue', label = "Wind Speeds from 10/09 to 10/12", figsize = (20, 10), ax = ax)
ax.set_xlabel("Time Elapsed")
ax.set_ylabel("Wind Speed in m/s")
ax.legend()

#Make the dates one long time series.
#Combine the data.
#Concatenate net cdf files together.
#NCO Operators.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import figure
from windrose import WindroseAxes
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import csv

df = pd.read_csv('RecentWindData1012-1014.csv', encoding='utf-8')
df.head(18)
windSpeedList = df['Wind Speed'].tolist()
windDirList = df['Wind Direction'].tolist()
ax = WindroseAxes.from_ax()
ax.bar(windDirList, windSpeedList, normed=False, opening=0.8, edgecolor='white')
ax.set_legend()
#normed = true normalizes the data so whwne set to false it shows the numbr of times that particular wind speed showed up in the data.
#Convert to mph and put units...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import figure
from windrose import WindroseAxes
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import csv

df = pd.read_csv('WindData1009-1011.csv', encoding='utf-8')
df.head(18)
windSpeedList = df['Wind Speed'].tolist()
windDirList = df['Wind Direction'].tolist()
ax = WindroseAxes.from_ax()
ax.bar(windDirList, windSpeedList, normed=False, opening=0.8, edgecolor='white')
ax.set_legend()
